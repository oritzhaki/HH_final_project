# %% [markdown]
# ![image.png](attachment:image.png)
#
# where:
#
# $f_{sampling}$ is the sampling frequency of the data in Hz. </br>
# $f_{cutoff}$ is the cutoff frequency of the filter in Hz. </br>
# $n$ is the order of the filter. </br>
# $s$ is the complex frequency variable. </br>
# $\epsilon$ is the passband ripple parameter. </br>
# $\delta$ is the maximum allowable passband ripple. </br>
# $\omega_c$ is the cutoff frequency in radians per second. </br>
# $N$ is the order of the filter. </br>
# $s_k$ are the complex frequencies of the poles of the filter. </br>
# $H(s)$ is the transfer function of the filter. </br>
# $a_k$ and $b_k$ are the coefficients of the filter. </br>
